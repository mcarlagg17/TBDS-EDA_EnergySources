# %% [markdown]
# # <a id='0'>ESPAÑA y sus FUENTES de ENERGÍA</h1>
# ![FuentesEnergia](
# img_energia.webp)

# %% [markdown]
# ## *ÍNDICE:*
# ---
# - [ 1. ANÁLISIS EXPLORATORIO DE DATOS (EDA):](#1)
#     - [1.1. Hipótesis](#11)
#     - [1.2. Acondicionamiento bases de datos](#12)
#     - [1.3. Análisis visual](#13)
#         - [1.3.1. Evolución energías en España](#131)
#         - [1.3.2. Energía generada vs energía demandada](#132)
#         - [1.3.3. Balance eficiencia energética-efectos adversos](#133)
#         - [1.3.4. Influencia del clima en la generación de energía](#134)
#     - [1.4. Análisis estadístico](#14)
#         - [1.4.1. Evolución energías en España](#141)
#         - [1.4.2. Energía generada vs energía demandada](#142)
#         - [1.4.3. Balance eficiencia energética-efectos adversos](#143)
#         - [1.4.4. Influencia del clima en la generación de energía](#144)
# - [2. CONCLUSIONES](#2)
# ---

# %% [markdown]
# ### *Contacto:*
# ___
# * Email: ***carla.glezz@gmail.com***
# * Linkedin: ***https://www.linkedin.com/in/mariacarlagonzalezgonzalez/***
# ---
# ---

# %% [markdown]
#
# # **1. Análisis Exploratio de Datos (EDA)**<a id='1'></a>

# %% [markdown]
# ##  **1.1. Hipótesis**<a id='11'></a>

# %% [markdown]
# ### **¿Energía a invertir en España?** 🤔
#
# 1. **¿Progresión de las distintas fuentes de energía en España en los últimos años?**
#     * Hipótesis: previsiblemente hay un aumento en renovables
#     * ¿Energía o energías que más generan?
#
#
# 2. **¿Autoabastecimiento?**
#     * ¿Coinciden la energía que consume España con la que genera?
#         + Excedente podría indicar la exportación y un deficit la importación.
#         + Otra posibilidad es falta de datos en alguno de los resultados.
#         (Se está trabajando en el almacenaje de energía pero de momento no es una tecnología en uso)
#     * En función de la demanda/consumo anual de energía en España, ¿cuánto faltaría para autoabastecerse?
#
#
# 3. **¿Eficiencia vs efectos adversos?** (elegiendo 3 de las energías con mayor probabilidad de ser nuestra elección final)
#     * ¿Se puede encontrar un equilibrio? ¿Cómo nos afecta?
#
#
# 4. **¿Influencia del clima?**
#     * Es previsible que sea afirmativa la respuesta, sobretodo en renovables.
#         + Los datos son una muestra, es necesario verificar que es suficiente y representativa de la población.
#     * ¿Se considera significativa esta influencia?
#         + Es posible que halla otros factores más significativos, como pueden ser la potencia instalada, la tecnología empleada,etc.
#
#
# 5. **Análisis económico** *(Punto a estudiar más adelante)*
#     * ¿Cuales son las fuentes más baratas?
#     * ¿Cuales son las más rentables?
#     * ¿Las que más generan son las más rentables económicamente?
#     * ¿Se puede hallar, si no lo hubiera, entre eficiencia energética y rentabilidad económica?

# %% [markdown]
# ##  **1.2. Acondicionamiento bases de datos**<a id='12'></a>

# %%
# Librery
from utils.utilsEDA import *

# %%
# Read all csv 

# NOTA IMPORTANTE: Copiar path hasta la carpeta 'scr' (único cambio para funcionamiento)
preroot='/Users/mcgg/Documents/TheBridge_DataScience_py_local/02_DATA_ANALISIS/EDA_MC/EDA-energia/energy-data/src'

df_spn=pd.read_csv(preroot+'/data/spn_energy_data.csv')
df_weather_spn=pd.read_csv(preroot+'/data/spn_weather_features.csv')

# %% [markdown]
# ### *Extracción inicial info. de los CSVs*

# %%
print('* Datos energía España: *')
df_spn.info()
# Out:
# * Datos energía España: *
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 29 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   time                                         35064 non-null  object
#  1   generation biomass                           35045 non-null  float64
#  2   generation fossil brown coal/lignite         35046 non-null  float64
#  3   generation fossil coal-derived gas           35046 non-null  float64
#  4   generation fossil gas                        35046 non-null  float64
#  5   generation fossil hard coal                  35046 non-null  float64
#  6   generation fossil oil                        35045 non-null  float64
#  7   generation fossil oil shale                  35046 non-null  float64
#  8   generation fossil peat                       35046 non-null  float64
#  9   generation geothermal                        35046 non-null  float64
#  10  generation hydro pumped storage aggregated   0 non-null      float64
#  11  generation hydro pumped storage consumption  35045 non-null  float64
#  12  generation hydro run-of-river and poundage   35045 non-null  float64
#  13  generation hydro water reservoir             35046 non-null  float64
#  14  generation marine                            35045 non-null  float64
#  15  generation nuclear                           35047 non-null  float64
#  16  generation other                             35046 non-null  float64
#  17  generation other renewable                   35046 non-null  float64
#  18  generation solar                             35046 non-null  float64
#  19  generation waste                             35045 non-null  float64
#  20  generation wind offshore                     35046 non-null  float64
#  21  generation wind onshore                      35046 non-null  float64
#  22  forecast solar day ahead                     35064 non-null  float64
#  23  forecast wind offshore eday ahead            0 non-null      float64
#  24  forecast wind onshore day ahead              35064 non-null  float64
#  25  total load forecast                          35064 non-null  float64
#  26  total load actual                            35028 non-null  float64
#  27  price day ahead                              35064 non-null  float64
#  28  price actual                                 35064 non-null  float64
# dtypes: float64(28), object(1)
# memory usage: 7.8+ MB

# %%
print('* Datos clima España: *')
df_weather_spn.info()
# Out:
# * Datos clima España: *
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178396 entries, 0 to 178395
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dt_iso               178396 non-null  object
#  1   city_name            178396 non-null  object
#  2   temp                 178396 non-null  float64
#  3   temp_min             178396 non-null  float64
#  4   temp_max             178396 non-null  float64
#  5   pressure             178396 non-null  int64
#  6   humidity             178396 non-null  int64
#  7   wind_speed           178396 non-null  int64
#  8   wind_deg             178396 non-null  int64
#  9   rain_1h              178396 non-null  float64
#  10  rain_3h              178396 non-null  float64
#  11  snow_3h              178396 non-null  float64
#  12  clouds_all           178396 non-null  int64
#  13  weather_id           178396 non-null  int64
#  14  weather_main         178396 non-null  object
#  15  weather_description  178396 non-null  object
#  16  weather_icon         178396 non-null  object
# dtypes: float64(6), int64(6), object(5)
# memory usage: 23.1+ MB

# %% [markdown]
# ### *Tratamiento bases de datos:*

# %% [markdown]
# #### csv generación energía España
#
# ```df_spn```: DataFrame que contiene los datos de energía en españa recogidos desde 1 enero 2015 hasta 31 diciembre 2018

# %% [markdown]
# |column	|description	|
# |-------|---------------|
# |time|fecha y hora|
# |generation biomass|energía generada, en MWh, provieniente de biomasa (fuente renovable)|
# |generation fossil brown coal/lignite|energía generada, en MWh, provieniente de derivados fósiles (fuente no renovable)|
# |generation fossil bcoal-derived gas|energía generada, en MWh, provieniente de derivados fósiles (fuente no renovable)|
# |generation fossil gas|energía generada, en MWh, provieniente de derivados fósiles (fuente no renovable)|
# |generation fossil hard coal|energía generada, en MWh, provieniente de derivados fósiles (fuente no renovable)|
# |generation fossil oil|energía generada, en MWh, provieniente de derivados fósiles (fuente no renovable)|
# |generation fossil oil shale|energía generada, en MWh, provieniente de derivados fósiles (fuente no renovable)|
# |generation fossil peat|energía generada, en MWh, provieniente de derivados fósiles (fuente no renovable)|
# |generation geothermal|energía geotérmica generada, en MWh (fuente renovable)|
# |generation hydro pumped storage aggregated|energía hidroeléctrica generada, en MWh (fuente renovable)|
# |generation hydro pumped storage consumption|energía hidroeléctrica generada, en MWh (fuente renovable)|
# |generation hydro run-of-river and poundage|energía hidroeléctrica generada, en MWh (fuente renovable)|
# |generation hydro water reservoir|energía hidroeléctrica generada, en MWh (fuente renovable)|
# |generation marine|energía marina generada, en MWh (fuente renovable)|
# |generation nuclear|energía nuclear generada, en MWh (fuente no renovable)|
# |generation other|energía generada no renovable que engloba las fuentes restantes, en MWh (fuente no renovable)|
# |generation other renewable|energía generada renovable que engloba las fuentes restantes, en MWh (fuente renovable)|
# |generation solar|energía generada, en MWh, provieniente del sol (fuente renovable)|
# |generation waste|energía generada, en MWh, provieniente de residuos/cogeneración (fuente no renovable)|
# |generation wind offshore|energía generada, en MWh, provieniente del viento no situado en tierra (fuente renovable)|
# |generation wind onshore|energía generada, en MWh, provieniente del viento situado en tierra (fuente renovable)|
# |forecast solar day ahead|--|
# |forecast wind offshore eday ahead|--|
# |forecast wind onshore day ahead|--|
# |total load forecast|--|
# |total load actual|--|
# |price day ahead|--|
# |price actual|--|

# %%
print('Número de columnas: ',len(df_spn.columns))
df_spn.columns
# Out:
# Número de columnas:  29
# Index(['time', 'generation biomass', 'generation fossil brown coal/lignite',
#        'generation fossil coal-derived gas', 'generation fossil gas',
#        'generation fossil hard coal', 'generation fossil oil',
#        'generation fossil oil shale', 'generation fossil peat',
#        'generation geothermal', 'generation hydro pumped storage aggregated',
#        'generation hydro pumped storage consumption',
#        'generation hydro run-of-river and poundage',
#        'generation hydro water reservoir', 'generation marine',
#        'generation nuclear', 'generation other', 'generation other renewable',
#        'generation solar', 'generation waste', 'generation wind offshore',
#        'generation wind onshore', 'forecast solar day ahead',
#        'forecast wind offshore eday ahead', 'forecast wind onshore day ahead',
#        'total load forecast', 'total load actual', 'price day ahead',
#        'price actual'],
#       dtype='object')

# %%
df_spn.tail()
# Out:
#                             time  generation biomass  \
# 35059  2018-12-31 19:00:00+01:00               297.0
# 35060  2018-12-31 20:00:00+01:00               296.0
# 35061  2018-12-31 21:00:00+01:00               292.0
# 35062  2018-12-31 22:00:00+01:00               293.0
# 35063  2018-12-31 23:00:00+01:00               290.0
#
#        generation fossil brown coal/lignite  \
# 35059                                   0.0
# 35060                                   0.0
# 35061                                   0.0
# 35062                                   0.0
# 35063                                   0.0
#
#        generation fossil coal-derived gas  generation fossil gas  \
# 35059                                 0.0                 7634.0
# 35060                                 0.0                 7241.0
# 35061                                 0.0                 7025.0
# 35062                                 0.0                 6562.0
# 35063                                 0.0                 6926.0
#
#        generation fossil hard coal  generation fossil oil  \
# 35059                       2628.0                  178.0
# 35060                       2566.0                  174.0
# 35061                       2422.0                  168.0
# 35062                       2293.0                  163.0
# 35063                       2166.0                  163.0
#
#        generation fossil oil shale  generation fossil peat  \
# 35059                          0.0                     0.0
# 35060                          0.0                     0.0
# 35061                          0.0                     0.0
# 35062                          0.0                     0.0
# 35063                          0.0                     0.0
#
#        generation geothermal  ...  generation waste  generation wind offshore  \
# 35059                    0.0  ...             277.0                       0.0
# 35060                    0.0  ...             280.0                       0.0
# 35061                    0.0  ...             286.0                       0.0
# 35062                    0.0  ...             287.0                       0.0
# 35063                    0.0  ...             287.0                       0.0
#
#        generation wind onshore  forecast solar day ahead  \
# 35059                   3113.0                      96.0
# 35060                   3288.0                      51.0
# 35061                   3503.0                      36.0
# 35062                   3586.0                      29.0
# 35063                   3651.0                      26.0
#
#        forecast wind offshore eday ahead  forecast wind onshore day ahead  \
# 35059                                NaN                           3253.0
# 35060                                NaN                           3353.0
# 35061                                NaN                           3404.0
# 35062                                NaN                           3273.0
# 35063                                NaN                           3117.0
#
#        total load forecast  total load actual  price day ahead  price actual
# 35059              30619.0            30653.0            68.85         77.02
# 35060              29932.0            29735.0            68.40         76.16
# 35061              27903.0            28071.0            66.88         74.30
# 35062              25450.0            25801.0            63.93         69.89
# 35063              24424.0            24455.0            64.27         69.88
#
# [5 rows x 29 columns]

# %%
# Se reemplaza 'time' quitándole el intervalo
df_spn['time']=df_spn['time'].replace({'\+01:00|\+02:00|\+03:00':''},regex=True)

# Se transforma en formato datetime la columna 'time' 
df_spn['time_dt']=pd.to_datetime(df_spn['time'], infer_datetime_format=True)
df_spn.columns
# Out:
# Index(['time', 'generation biomass', 'generation fossil brown coal/lignite',
#        'generation fossil coal-derived gas', 'generation fossil gas',
#        'generation fossil hard coal', 'generation fossil oil',
#        'generation fossil oil shale', 'generation fossil peat',
#        'generation geothermal', 'generation hydro pumped storage aggregated',
#        'generation hydro pumped storage consumption',
#        'generation hydro run-of-river and poundage',
#        'generation hydro water reservoir', 'generation marine',
#        'generation nuclear', 'generation other', 'generation other renewable',
#        'generation solar', 'generation waste', 'generation wind offshore',
#        'generation wind onshore', 'forecast solar day ahead',
#        'forecast wind offshore eday ahead', 'forecast wind onshore day ahead',
#        'total load forecast', 'total load actual', 'price day ahead',
#        'price actual', 'time_dt'],
#       dtype='object')

# %%
# Se eliminan las filas y columnas que contengan NaN en todos sus elementos 
comp_colna_filna(df_spn,['time'])
df_spn=del_colna_filna(df_spn,['time'])
print('Nº de columnas actuales:',len(df_spn.columns))
# Out:
# Se mantienen las mismas filas: True y columnas: False
# Número fil y col antes (35064, 30) Número fil y col después (35064, 28)
# Nº de columnas actuales: 28

# %%
# Se comprueba los NaN restantes de cada fila 
df_spn.isna().sum()
# Out:
# time                                            0
# generation biomass                             19
# generation fossil brown coal/lignite           18
# generation fossil coal-derived gas             18
# generation fossil gas                          18
# generation fossil hard coal                    18
# generation fossil oil                          19
# generation fossil oil shale                    18
# generation fossil peat                         18
# generation geothermal                          18
# generation hydro pumped storage consumption    19
# generation hydro run-of-river and poundage     19
# generation hydro water reservoir               18
# generation marine                              19
# generation nuclear                             17
# generation other                               18
# generation other renewable                     18
# generation solar                               18
# generation waste                               19
# generation wind offshore                       18
# generation wind onshore                        18
# forecast solar day ahead                        0
# forecast wind onshore day ahead                 0
# total load forecast                             0
# total load actual                              36
# price day ahead                                 0
# price actual                                    0
# time_dt                                         0
# dtype: int64

# %%
# Se van rellenando columnas hacia delante, es decir, cogiendo el valor anterior 
df_spn.fillna(method='ffill',inplace=True) 
# Se obtiene así un dataset libre de NaN
df_spn.isna().sum()
# Out:
# time                                           0
# generation biomass                             0
# generation fossil brown coal/lignite           0
# generation fossil coal-derived gas             0
# generation fossil gas                          0
# generation fossil hard coal                    0
# generation fossil oil                          0
# generation fossil oil shale                    0
# generation fossil peat                         0
# generation geothermal                          0
# generation hydro pumped storage consumption    0
# generation hydro run-of-river and poundage     0
# generation hydro water reservoir               0
# generation marine                              0
# generation nuclear                             0
# generation other                               0
# generation other renewable                     0
# generation solar                               0
# generation waste                               0
# generation wind offshore                       0
# generation wind onshore                        0
# forecast solar day ahead                       0
# forecast wind onshore day ahead                0
# total load forecast                            0
# total load actual                              0
# price day ahead                                0
# price actual                                   0
# time_dt                                        0
# dtype: int64

# %%
# Se eligen las columnas con las que se va a trabajar
df_spn=df_spn.loc[:,df_spn.columns.str.startswith('generation')+df_spn.columns.str.startswith('time')]
# Se eliminan las columnas que todos sus datos sean 0, dado que indica el no registro de esa variable 
[df_spn.drop(columns=col,inplace=True) for col in df_spn.columns if (df_spn[col]==0).sum()==len(df_spn)]
df_spn.head()
# Out:
#                   time  generation biomass  \
# 0  2015-01-01 00:00:00               447.0
# 1  2015-01-01 01:00:00               449.0
# 2  2015-01-01 02:00:00               448.0
# 3  2015-01-01 03:00:00               438.0
# 4  2015-01-01 04:00:00               428.0
#
#    generation fossil brown coal/lignite  generation fossil gas  \
# 0                                 329.0                 4844.0
# 1                                 328.0                 5196.0
# 2                                 323.0                 4857.0
# 3                                 254.0                 4314.0
# 4                                 187.0                 4130.0
#
#    generation fossil hard coal  generation fossil oil  \
# 0                       4821.0                  162.0
# 1                       4755.0                  158.0
# 2                       4581.0                  157.0
# 3                       4131.0                  160.0
# 4                       3840.0                  156.0
#
#    generation hydro pumped storage consumption  \
# 0                                        863.0
# 1                                        920.0
# 2                                       1164.0
# 3                                       1503.0
# 4                                       1826.0
#
#    generation hydro run-of-river and poundage  \
# 0                                      1051.0
# 1                                      1009.0
# 2                                       973.0
# 3                                       949.0
# 4                                       953.0
#
#    generation hydro water reservoir  generation nuclear  generation other  \
# 0                            1899.0              7096.0              43.0
# 1                            1658.0              7096.0              43.0
# 2                            1371.0              7099.0              43.0
# 3                             779.0              7098.0              43.0
# 4                             720.0              7097.0              43.0
#
#    generation other renewable  generation solar  generation waste  \
# 0                        73.0              49.0             196.0
# 1                        71.0              50.0             195.0
# 2                        73.0              50.0             196.0
# 3                        75.0              50.0             191.0
# 4                        74.0              42.0             189.0
#
#    generation wind onshore             time_dt
# 0                   6378.0 2015-01-01 00:00:00
# 1                   5890.0 2015-01-01 01:00:00
# 2                   5461.0 2015-01-01 02:00:00
# 3                   5238.0 2015-01-01 03:00:00
# 4                   4935.0 2015-01-01 04:00:00

# %%
# Se comprueban los outliers:

print(f'Filas totales: {len(df_spn)}\n')
print('Número de outliers por columna:\n')
for col in df_spn.loc[:,df_spn.columns.str.startswith('generation')]:
    print(col,':',outlier(df_spn[col]))
# Out:
# Filas totales: 35064
#
# Número de outliers por columna:
#
# generation biomass : 87
# generation fossil brown coal/lignite : 0
# generation fossil gas : 2185
# generation fossil hard coal : 0
# generation fossil oil : 246
# generation hydro pumped storage consumption : 3762
# generation hydro run-of-river and poundage : 0
# generation hydro water reservoir : 343
# generation nuclear : 79
# generation other : 1267
# generation other renewable : 5
# generation solar : 0
# generation waste : 328
# generation wind onshore : 377

# %% [markdown]
# ---
# *Agrupaciones*:
#
# ---

# %%
# Agrupaciones según origen:
fosil=['generation fossil brown coal/lignite',
       'generation fossil gas', 'generation fossil hard coal',
       'generation fossil oil']

hydro=['generation hydro pumped storage consumption',
       'generation hydro run-of-river and poundage',
       'generation hydro water reservoir']
       
# División entre renovables y no renovables:
rnw_0=['generation biomass', 'generation hydro pumped storage consumption',
       'generation hydro run-of-river and poundage',
       'generation hydro water reservoir',
       'generation other renewable', 'generation solar',
       'generation wind onshore']
       
nrnw_0=['generation fossil brown coal/lignite',
       'generation fossil gas', 'generation fossil hard coal',
       'generation fossil oil','generation nuclear',
       'generation other','generation waste']

rnw=['generation biomass', 'generation hydro',
       'generation other renewable', 'generation solar',
       'generation wind onshore']
       
nrnw=['generation fossil','generation nuclear',
       'generation other','generation waste']

# Selección de columnas:
columns_0=['generation wind onshore','generation solar','generation fossil gas','generation fossil hard coal','generation nuclear']
# Elegidas para análisis posterior (las hydro tienen limitación geográfica, por eso no se han incluido)
columns=['generation wind onshore','generation solar','generation fossil','generation nuclear']

# %%
df_spn['generation fossil'] = df_spn[fosil].sum(axis=1)
df_spn['generation hydro'] = df_spn[hydro].sum(axis=1)
df_spn.drop(columns=fosil+hydro,inplace=True)
df_spn.head()
# Out:
#                   time  generation biomass  generation nuclear  \
# 0  2015-01-01 00:00:00               447.0              7096.0
# 1  2015-01-01 01:00:00               449.0              7096.0
# 2  2015-01-01 02:00:00               448.0              7099.0
# 3  2015-01-01 03:00:00               438.0              7098.0
# 4  2015-01-01 04:00:00               428.0              7097.0
#
#    generation other  generation other renewable  generation solar  \
# 0              43.0                        73.0              49.0
# 1              43.0                        71.0              50.0
# 2              43.0                        73.0              50.0
# 3              43.0                        75.0              50.0
# 4              43.0                        74.0              42.0
#
#    generation waste  generation wind onshore             time_dt  \
# 0             196.0                   6378.0 2015-01-01 00:00:00
# 1             195.0                   5890.0 2015-01-01 01:00:00
# 2             196.0                   5461.0 2015-01-01 02:00:00
# 3             191.0                   5238.0 2015-01-01 03:00:00
# 4             189.0                   4935.0 2015-01-01 04:00:00
#
#    generation fossil  generation hydro
# 0            10156.0            3813.0
# 1            10437.0            3587.0
# 2             9918.0            3508.0
# 3             8859.0            3231.0
# 4             8313.0            3499.0

# %%
# Agrupaciones por hora, día, mes y año: 
df_spn_day=df_spn.copy()
df_spn_day['day']=df_spn_day['time'].replace({'| \d+\d+:\d+\d+:\d+\d+|':''},regex=True)

df_spn_year=df_spn_day.copy()

# Se crea una columna tipo datatime llamada 'day_dt' equivale al str de 'time' 
df_spn_year['day_dt']=pd.to_datetime(df_spn_day['day'], infer_datetime_format=True)

df_spn_month=df_spn_year.groupby(df_spn_year['day_dt'].dt.month).mean()
df_spn_year=df_spn_year.groupby(df_spn_year['day_dt'].dt.year).mean()

# Se divide en años: 
df_spn_day_2015=df_spn_day.loc[df_spn_day['day'].str.startswith('2015'),:]
df_spn_day_2016=df_spn_day.loc[df_spn_day['day'].str.startswith('2016'),:]
df_spn_day_2017=df_spn_day.loc[df_spn_day['day'].str.startswith('2017'),:]
df_spn_day_2018=df_spn_day.loc[df_spn_day['day'].str.startswith('2018'),:]

# Se agrupa por fecha: se realiza la media de todas las horas del día.
df_spn_day=df_spn_day.groupby('day').mean()

# Se agrupa por los meses de cada año:
df_spn_day_i=[df_spn_day_2015,df_spn_day_2016,df_spn_day_2017,df_spn_day_2018]


for i in df_spn_day_i:
    i['month_dt']=pd.to_datetime(i['day'], infer_datetime_format=True)

df_spn_month_2015=df_spn_day_2015.groupby(df_spn_day_2015['month_dt'].dt.month).mean()
df_spn_month_2016=df_spn_day_2016.groupby(df_spn_day_2016['month_dt'].dt.month).mean()
df_spn_month_2017=df_spn_day_2017.groupby(df_spn_day_2017['month_dt'].dt.month).mean()
df_spn_month_2018=df_spn_day_2018.groupby(df_spn_day_2018['month_dt'].dt.month).mean()

# %%
# Reordenar -No renovables y después renovables-

df_spn_day['month']= pd.to_datetime(df_spn_day.index).month
df_spn_day['year']= pd.to_datetime(df_spn_day.index).year
df_spn_day_=df_spn_day[['month','year']+nrnw+rnw]
df_spn_day_.head()
# Out:
#             month  year  generation fossil  generation nuclear  \
# day
# 2015-01-01      1  2015        8920.916667         7097.000000
# 2015-01-02      1  2015        4976.291667         7105.833333
# 2015-01-03      1  2015        5015.125000         7095.375000
# 2015-01-04      1  2015        6069.958333         7083.625000
# 2015-01-05      1  2015        7360.833333         3910.375000
#
#             generation other  generation waste  generation biomass  \
# day
# 2015-01-01         42.250000        202.166667          428.500000
# 2015-01-02         44.250000        185.250000          385.291667
# 2015-01-03         78.041667        203.958333          440.500000
# 2015-01-04         83.708333        159.291667          397.125000
# 2015-01-05         39.166667        152.583333          364.500000
#
#             generation hydro  generation other renewable  generation solar  \
# day
# 2015-01-01       4285.166667                   73.958333       1143.458333
# 2015-01-02       6552.166667                   61.375000       1252.208333
# 2015-01-03       6682.625000                   66.583333       1119.625000
# 2015-01-04       5326.583333                   57.458333       2402.500000
# 2015-01-05       4770.416667                   73.666667       1631.541667
#
#             generation wind onshore
# day
# 2015-01-01              3708.416667
# 2015-01-02             11225.375000
# 2015-01-03              9167.416667
# 2015-01-04              8065.666667
# 2015-01-05              7801.833333

# %% [markdown]
# #### csv clima España
#
# ```df_weather_spn```: DataFrame que contiene los datos del clima en españa recogidos desde 1 enero 2015 hasta 31 diciembre 2018

# %% [markdown]
# |column	|description	|
# |-------|---------------|
# |dt_iso||
# |city_name||
# |temp||
# |temp_min||
# |temp_max||
# |pressure||
# |humidity||
# |wind_speed||
# |wind_deg||
# |rain_1h||
# |rain_3h||
# |snow_3h||
# |clouds_all||
# |weather_id||
# |weather_main||
# |weather_description||
# |weather_icon||

# %%
df_weather_spn.city_name.unique()
# Out:
# array(['Valencia', 'Madrid', 'Bilbao', ' Barcelona', 'Seville'],
#       dtype=object)

# %%
df_weather_spn.columns
# Out:
# Index(['dt_iso', 'city_name', 'temp', 'temp_min', 'temp_max', 'pressure',
#        'humidity', 'wind_speed', 'wind_deg', 'rain_1h', 'rain_3h', 'snow_3h',
#        'clouds_all', 'weather_id', 'weather_main', 'weather_description',
#        'weather_icon'],
#       dtype='object')

# %%
[df_weather_spn[col].unique() for col in ['clouds_all', 'weather_id', 'weather_main', 'weather_description',
       'weather_icon']]
# Out:
# [array([  0,   8,  12,   4,  24,  44,  64,  82,  92,  88,  48,  68,  80,
#          27,  50,  32,  20,  26,  46,   6,  36,  22,  45,  21,  60,  52,
#          76,  56,  91,  90,  89,  65,  42,  70,  53,  34,  28,  16,  14,
#           5,   2,  38,  10,  18,  86,  78,  54,  29,  72,  84,  74,  15,
#          62,  58,  69,  73,  40,  51,  75,  30,  49,  37,  17,  57,  13,
#          66,  25,  81,  77,  33,  61,   9,  41,  35,  47,  83,  43,  55,
#          59,  71,  87,  67,  79, 100,   7,  19,  39,  23,  95,  96,  85,
#           3,  94,  97,  11,  63,  93]),
#  array([800, 801, 802, 803, 804, 500, 501, 502, 701, 522, 521, 503, 202,
#         200, 201, 211, 520, 300, 741, 301, 711, 302, 721, 310, 600, 616,
#         615, 601, 210, 602, 611, 311, 612, 620, 531, 731, 761, 771]),
#  array(['clear', 'clouds', 'rain', 'mist', 'thunderstorm', 'drizzle',
#         'fog', 'smoke', 'haze', 'snow', 'dust', 'squall'], dtype=object),
#  array(['sky is clear', 'few clouds', 'scattered clouds', 'broken clouds',
#         'overcast clouds', 'light rain', 'moderate rain',
#         'heavy intensity rain', 'mist', 'heavy intensity shower rain',
#         'shower rain', 'very heavy rain', 'thunderstorm with heavy rain',
#         'thunderstorm with light rain', 'thunderstorm with rain',
#         'proximity thunderstorm', 'thunderstorm',
#         'light intensity shower rain', 'light intensity drizzle', 'fog',
#         'drizzle', 'smoke', 'heavy intensity drizzle', 'haze',
#         'proximity shower rain', 'light intensity drizzle rain',
#         'light snow', 'rain and snow', 'light rain and snow', 'snow',
#         'light thunderstorm', 'heavy snow', 'sleet', 'rain and drizzle',
#         'shower sleet', 'light shower sleet', 'light shower snow',
#         'proximity moderate rain', 'ragged shower rain',
#         'sand dust whirls', 'proximity drizzle', 'dust', 'squalls'],
#        dtype=object),
#  array(['01n', '01d', '01', '02n', '02d', '02', '03', '04n', '04', '10n',
#         '03n', '10', '04d', '03d', '10d', '50d', '09n', '11d', '11n',
#         '09d', '50n', '13d', '13n', '13'], dtype=object)]

# %%
df_weather_spn.isna().sum()
# Out:
# dt_iso                 0
# city_name              0
# temp                   0
# temp_min               0
# temp_max               0
# pressure               0
# humidity               0
# wind_speed             0
# wind_deg               0
# rain_1h                0
# rain_3h                0
# snow_3h                0
# clouds_all             0
# weather_id             0
# weather_main           0
# weather_description    0
# weather_icon           0
# dtype: int64

# %%
# Visualización de outliers:
df_weather_spn.boxplot(rot='90')
# Out:
# <AxesSubplot:>

# %%
df_weather_spn.drop(columns=['weather_description', 'weather_icon','rain_3h','temp_min', 'temp_max', 'wind_deg'],inplace=True)

# %%
df_weather_spn.loc[df_weather_spn.pressure > 1051, 'pressure'] = np.nan
df_weather_spn.loc[df_weather_spn.pressure < 931, 'pressure'] = np.nan

# %%
df_weather_spn.loc[df_weather_spn.wind_speed > 50, 'wind_speed'] = np.nan
df_weather_spn.interpolate(method='linear', limit_direction='forward', inplace=True, axis=0)

# %%
df_weather_spn.boxplot(rot='90')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
# Agrupaciones:
#
# ---

# %%
df_weather_spn['dt_iso']=df_weather_spn['dt_iso'].replace({'\+01:00|\+02:00|\+03:00':''},regex=True)
df_weather_spn['time']=pd.to_datetime(df_weather_spn['dt_iso'], infer_datetime_format=True)

# %%
df_weather_spn = df_weather_spn.drop(['dt_iso'], axis=1)
df_weather_spn_=df_weather_spn.copy()
#df_weather_spn=df_weather_spn.set_index('time')

# %%
df_weather_spn
# Out:
#        city_name     temp  pressure  humidity  wind_speed  rain_1h  snow_3h  \
# 0       Valencia  270.475    1001.0        77         1.0      0.0      0.0
# 1       Valencia  270.475    1001.0        77         1.0      0.0      0.0
# 2       Valencia  269.686    1002.0        78         0.0      0.0      0.0
# 3       Valencia  269.686    1002.0        78         0.0      0.0      0.0
# 4       Valencia  269.686    1002.0        78         0.0      0.0      0.0
# ...          ...      ...       ...       ...         ...      ...      ...
# 178391   Seville  287.760    1028.0        54         3.0      0.0      0.0
# 178392   Seville  285.760    1029.0        62         3.0      0.0      0.0
# 178393   Seville  285.150    1028.0        58         4.0      0.0      0.0
# 178394   Seville  284.150    1029.0        57         4.0      0.0      0.0
# 178395   Seville  283.970    1029.0        70         3.0      0.0      0.0
#
#         clouds_all  weather_id weather_main                time
# 0                0         800        clear 2015-01-01 00:00:00
# 1                0         800        clear 2015-01-01 01:00:00
# 2                0         800        clear 2015-01-01 02:00:00
# 3                0         800        clear 2015-01-01 03:00:00
# 4                0         800        clear 2015-01-01 04:00:00
# ...            ...         ...          ...                 ...
# 178391           0         800        clear 2018-12-31 19:00:00
# 178392           0         800        clear 2018-12-31 20:00:00
# 178393           0         800        clear 2018-12-31 21:00:00
# 178394           0         800        clear 2018-12-31 22:00:00
# 178395           0         800        clear 2018-12-31 23:00:00
#
# [178396 rows x 11 columns]

# %%
df_1, df_2, df_3, df_4, df_5 = [x for _, x in df_weather_spn.groupby('city_name')]
dfs = [df_1, df_2, df_3, df_4, df_5]

# %%
df_spn_=df_spn.copy()
df_spn_['time']=df_spn['time_dt']
df_spn_.drop(columns='time_dt',inplace=True)
#df_spn_.set_index('time')

# %%
print(len(df_1),len(df_spn_))
# Out:
# 35476 35064

# %%
#df_spn_=df_spn_.set_index('time')

# %%
df_2
# Out:
#        city_name        temp  pressure  humidity  wind_speed  rain_1h  \
# 71412     Bilbao  269.657312    1036.0        97         0.0      0.0
# 71413     Bilbao  269.763500    1035.0        97         0.0      0.0
# 71414     Bilbao  269.251688    1036.0        97         1.0      0.0
# 71415     Bilbao  269.203344    1035.0        97         1.0      0.0
# 71416     Bilbao  269.485500    1035.0        97         1.0      0.0
# ...          ...         ...       ...       ...         ...      ...
# 107358    Bilbao  281.260000    1033.0        93         0.0      0.0
# 107359    Bilbao  279.810000    1034.0        93         1.0      0.0
# 107360    Bilbao  277.150000    1034.0       100         1.0      0.0
# 107361    Bilbao  276.600000    1034.0        93         1.0      0.0
# 107362    Bilbao  275.600000    1034.0        93         2.0      0.0
#
#         snow_3h  clouds_all  weather_id weather_main                time
# 71412       0.0           0         800        clear 2015-01-01 00:00:00
# 71413       0.0           0         800        clear 2015-01-01 01:00:00
# 71414       0.0           0         800        clear 2015-01-01 02:00:00
# 71415       0.0           0         800        clear 2015-01-01 03:00:00
# 71416       0.0           0         800        clear 2015-01-01 04:00:00
# ...         ...         ...         ...          ...                 ...
# 107358      0.0           0         800        clear 2018-12-31 19:00:00
# 107359      0.0           0         800        clear 2018-12-31 20:00:00
# 107360      0.0           0         800        clear 2018-12-31 21:00:00
# 107361      0.0           0         800        clear 2018-12-31 22:00:00
# 107362      0.0           0         800        clear 2018-12-31 23:00:00
#
# [35951 rows x 11 columns]

# %%
df_spn_
# Out:
#                      time  generation biomass  generation nuclear  \
# 0     2015-01-01 00:00:00               447.0              7096.0
# 1     2015-01-01 01:00:00               449.0              7096.0
# 2     2015-01-01 02:00:00               448.0              7099.0
# 3     2015-01-01 03:00:00               438.0              7098.0
# 4     2015-01-01 04:00:00               428.0              7097.0
# ...                   ...                 ...                 ...
# 35059 2018-12-31 19:00:00               297.0              6073.0
# 35060 2018-12-31 20:00:00               296.0              6074.0
# 35061 2018-12-31 21:00:00               292.0              6076.0
# 35062 2018-12-31 22:00:00               293.0              6075.0
# 35063 2018-12-31 23:00:00               290.0              6075.0
#
#        generation other  generation other renewable  generation solar  \
# 0                  43.0                        73.0              49.0
# 1                  43.0                        71.0              50.0
# 2                  43.0                        73.0              50.0
# 3                  43.0                        75.0              50.0
# 4                  43.0                        74.0              42.0
# ...                 ...                         ...               ...
# 35059              63.0                        95.0              85.0
# 35060              62.0                        95.0              33.0
# 35061              61.0                        94.0              31.0
# 35062              61.0                        93.0              31.0
# 35063              61.0                        92.0              31.0
#
#        generation waste  generation wind onshore  generation fossil  \
# 0                 196.0                   6378.0            10156.0
# 1                 195.0                   5890.0            10437.0
# 2                 196.0                   5461.0             9918.0
# 3                 191.0                   5238.0             8859.0
# 4                 189.0                   4935.0             8313.0
# ...                 ...                      ...                ...
# 35059             277.0                   3113.0            10440.0
# 35060             280.0                   3288.0             9981.0
# 35061             286.0                   3503.0             9615.0
# 35062             287.0                   3586.0             9018.0
# 35063             287.0                   3651.0             9255.0
#
#        generation hydro
# 0                3813.0
# 1                3587.0
# 2                3508.0
# 3                3231.0
# 4                3499.0
# ...                 ...
# 35059            5972.0
# 35060            5104.0
# 35061            4029.0
# 35062            3304.0
# 35063            2863.0
#
# [35064 rows x 10 columns]

# %%
df_spn_=df_spn_.groupby(pd.Grouper(key='time', axis=0, freq='D')).sum()
df_weather_spn=df_weather_spn.groupby(pd.Grouper(key='time', axis=0, freq='D')).sum()

# %%
df_weather_spn
# Out:
#                     temp  pressure  humidity  wind_speed  rain_1h  snow_3h  \
# time
# 2015-01-01  33231.461438  122639.0      9047       234.0      0.0      0.0
# 2015-01-02  33347.710219  122933.0      9340       189.0      0.0      0.0
# 2015-01-03  33458.143687  122489.0      9431       189.0      0.0      0.0
# 2015-01-04  33555.603687  121903.0      9212       151.0      5.1      0.0
# 2015-01-05  33483.950375  121741.0      9739       138.0      1.5      0.0
# ...                  ...       ...       ...         ...      ...      ...
# 2018-12-27  34526.350000  126343.0      9989       185.0      0.0      0.0
# 2018-12-28  34571.290000  126445.0     10159       240.0      0.3      0.0
# 2018-12-29  33747.790000  123525.0      9445       335.0      0.9      0.0
# 2018-12-30  34739.750000  127698.0      9232       351.0      0.0      0.0
# 2018-12-31  33933.030000  124657.0      8542       303.0      0.0      0.0
#
#             clouds_all  weather_id
# time
# 2015-01-01          92       96004
# 2015-01-02         717       96032
# 2015-01-03         274       96012
# 2015-01-04        1372       90912
# 2015-01-05        2138       94582
# ...                ...         ...
# 2018-12-27        2547       95965
# 2018-12-28        3848       92033
# 2018-12-29        2228       93625
# 2018-12-30        1760       98137
# 2018-12-31         910       96073
#
# [1461 rows x 8 columns]

# %%
df_weather_city = df_spn_

for df in dfs:
    city = df['city_name'].unique()
    city_str = str(city).replace("'", "").replace('[', '').replace(']', '').replace(' ', '')
    df = df.add_suffix('_{}'.format(city_str))
    df_weather_city = df_weather_city.merge(df, on=['time'], how='outer')
    df_weather_city = df_weather_city.drop('city_name_{}'.format(city_str), axis=1)
    
df_weather_city.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/mcgg/Documents/TheBridge_DataScience_py_local/02_DATA_ANALISIS/EDA_MC/EDA-energia/energy-data/src/EDA.ipynb Cell 51' in <module>
#       <a href='vscode-notebook-cell:/Users/mcgg/Documents/TheBridge_DataScience_py_local/02_DATA_ANALISIS/EDA_MC/EDA-energia/energy-data/src/EDA.ipynb#ch0000235?line=4'>5</a>     city_str = str(city).replace("'", "").replace('[', '').replace(']', '').replace(' ', '')
#       <a href='vscode-notebook-cell:/Users/mcgg/Documents/TheBridge_DataScience_py_local/02_DATA_ANALISIS/EDA_MC/EDA-energia/energy-data/src/EDA.ipynb#ch0000235?line=5'>6</a>     df = df.add_suffix('_{}'.format(city_str))
# ----> <a href='vscode-notebook-cell:/Users/mcgg/Documents/TheBridge_DataScience_py_local/02_DATA_ANALISIS/EDA_MC/EDA-energia/energy-data/src/EDA.ipynb#ch0000235?line=6'>7</a>     df_weather_city = df_weather_city.merge(df, on=['time'], how='outer')
#       <a href='vscode-notebook-cell:/Users/mcgg/Documents/TheBridge_DataScience_py_local/02_DATA_ANALISIS/EDA_MC/EDA-energia/energy-data/src/EDA.ipynb#ch0000235?line=7'>8</a>     df_weather_city = df_weather_city.drop('city_name_{}'.format(city_str), axis=1)
#      <a href='vscode-notebook-cell:/Users/mcgg/Documents/TheBridge_DataScience_py_local/02_DATA_ANALISIS/EDA_MC/EDA-energia/energy-data/src/EDA.ipynb#ch0000235?line=9'>10</a> df_weather_city.head()
#
# File ~/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py:9339, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9319'>9320</a> @Substitution("")
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9320'>9321</a> @Appender(_merge_doc, indents=2)
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9321'>9322</a> def merge(
#    (...)
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9334'>9335</a>     validate: str | None = None,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9335'>9336</a> ) -> DataFrame:
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9336'>9337</a>     from pandas.core.reshape.merge import merge
# -> <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9338'>9339</a>     return merge(
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9339'>9340</a>         self,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9340'>9341</a>         right,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9341'>9342</a>         how=how,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9342'>9343</a>         on=on,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9343'>9344</a>         left_on=left_on,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9344'>9345</a>         right_on=right_on,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9345'>9346</a>         left_index=left_index,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9346'>9347</a>         right_index=right_index,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9347'>9348</a>         sort=sort,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9348'>9349</a>         suffixes=suffixes,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9349'>9350</a>         copy=copy,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9350'>9351</a>         indicator=indicator,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9351'>9352</a>         validate=validate,
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/frame.py?line=9352'>9353</a>     )
#
# File ~/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=89'>90</a> @Substitution("\nleft : DataFrame or named Series")
#      <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=90'>91</a> @Appender(_merge_doc, indents=0)
#      <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=91'>92</a> def merge(
#    (...)
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=104'>105</a>     validate: str | None = None,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=105'>106</a> ) -> DataFrame:
# --> <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=106'>107</a>     op = _MergeOperation(
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=107'>108</a>         left,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=108'>109</a>         right,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=109'>110</a>         how=how,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=110'>111</a>         on=on,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=111'>112</a>         left_on=left_on,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=112'>113</a>         right_on=right_on,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=113'>114</a>         left_index=left_index,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=114'>115</a>         right_index=right_index,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=115'>116</a>         sort=sort,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=116'>117</a>         suffixes=suffixes,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=117'>118</a>         copy=copy,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=118'>119</a>         indicator=indicator,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=119'>120</a>         validate=validate,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=120'>121</a>     )
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=121'>122</a>     return op.get_result()
#
# File ~/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py:700, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=692'>693</a> self._cross = cross_col
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=694'>695</a> # note this function has side effects
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=695'>696</a> (
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=696'>697</a>     self.left_join_keys,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=697'>698</a>     self.right_join_keys,
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=698'>699</a>     self.join_names,
# --> <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=699'>700</a> ) = self._get_merge_keys()
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=701'>702</a> # validate the merge keys dtypes. We may need to coerce
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=702'>703</a> # to avoid incompatible dtypes
#     <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=703'>704</a> self._maybe_coerce_merge_keys()
#
# File ~/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1097, in _MergeOperation._get_merge_keys(self)
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1094'>1095</a> if not is_rkey(rk):
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1095'>1096</a>     if rk is not None:
# -> <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1096'>1097</a>         right_keys.append(right._get_label_or_level_values(rk))
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1097'>1098</a>     else:
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1098'>1099</a>         # work-around for merge_asof(right_index=True)
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/reshape/merge.py?line=1099'>1100</a>         right_keys.append(right.index)
#
# File ~/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/generic.py:1848, in NDFrame._get_label_or_level_values(self, key, axis)
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/generic.py?line=1845'>1846</a>     values = self.axes[axis].get_level_values(key)._values
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/generic.py?line=1846'>1847</a> else:
# -> <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/generic.py?line=1847'>1848</a>     raise KeyError(key)
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/generic.py?line=1849'>1850</a> # Check for duplicates
#    <a href='file:///Users/mcgg/opt/miniconda3/envs/the_bridge_ds/lib/python3.9/site-packages/pandas/core/generic.py?line=1850'>1851</a> if values.ndim > 1:
#
# KeyError: 'time'

# %%
df_weather_spn_ = df_spn_
df_weather_spn_ = df_weather_city.merge(df_weather_spn, on=['time'], how='outer')

    
df_weather_spn_.head()
# Out:
#             generation biomass  generation nuclear  generation other  \
# time
# 2015-01-01               447.0              7096.0              43.0
# 2015-01-01               447.0              7096.0              43.0
# 2015-01-01               447.0              7096.0              43.0
# 2015-01-01               447.0              7096.0              43.0
# 2015-01-01               447.0              7096.0              43.0
#
#             generation other renewable  generation solar  generation waste  \
# time
# 2015-01-01                        73.0              49.0             196.0
# 2015-01-01                        73.0              49.0             196.0
# 2015-01-01                        73.0              49.0             196.0
# 2015-01-01                        73.0              49.0             196.0
# 2015-01-01                        73.0              49.0             196.0
#
#             generation wind onshore  generation fossil  generation hydro  \
# time
# 2015-01-01                   6378.0            10156.0            3813.0
# 2015-01-01                   6378.0            10156.0            3813.0
# 2015-01-01                   6378.0            10156.0            3813.0
# 2015-01-01                   6378.0            10156.0            3813.0
# 2015-01-01                   6378.0            10156.0            3813.0
#
#             temp_Barcelona  ...   city_name        temp  pressure  humidity  \
# time                        ...
# 2015-01-01         281.625  ...    Valencia  270.475000    1001.0        77
# 2015-01-01         281.625  ...      Madrid  267.325000     971.0        63
# 2015-01-01         281.625  ...      Bilbao  269.657312    1036.0        97
# 2015-01-01         281.625  ...   Barcelona  281.625000    1035.0       100
# 2015-01-01         281.625  ...     Seville  273.375000    1039.0        75
#
#             wind_speed  rain_1h snow_3h  clouds_all  weather_id  weather_main
# time
# 2015-01-01         1.0      0.0     0.0           0         800         clear
# 2015-01-01         1.0      0.0     0.0           0         800         clear
# 2015-01-01         0.0      0.0     0.0           0         800         clear
# 2015-01-01         7.0      0.0     0.0           0         800         clear
# 2015-01-01         1.0      0.0     0.0           0         800         clear
#
# [5 rows x 62 columns]

# %%
df_weather_city.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ##  **1.3. Análisis visual**<a id='13'></a>

# %% [markdown]
# ### *Ajustes gráficas*

# %%
# Configuraciones gráficas:
sns.set(rc={'figure.figsize':(15, 10)})
plt.style.use('ggplot')
colors_0=['burlywood',
'tan',
'gray',
'darkgray',
'lightcoral',
'cadetblue',
'powderblue',
'slategray',
'lightgray',
'seagreen',
'khaki',
'lightseagreen',
'lemonchiffon',
'mediumaquamarine']
colors=['darkgray',
'lightcoral',
'lightgray',
'tan',
'slategray',
'cadetblue',
'lightseagreen',
'lemonchiffon',
'mediumaquamarine']
colorsrwn_0=['burlywood','cadetblue','powderblue',
'slategray','seagreen',
'khaki','mediumaquamarine']
colorsnrwn_0=['tan','gray','darkgray','lemonchiffon','lightcoral','lightgray','grey',
'brown']
colorsrwn=['slategray',
'cadetblue',
'lightseagreen',
'lemonchiffon',
'mediumaquamarine']
colorsnrwn=['darkgray',
'lightcoral',
'lightgray',
'tan']

# %% [markdown]
# ### *1.3.1. Evolución de las energías en España:* <a id='131'></a>

# %%
df_spn_day.boxplot(rot='90')
# Out:
# <AxesSubplot:>

# %%
# Se comprueban nuevamente los outliers tras agrupar:

print(f'Filas totales: {len(df_spn_day)}\n')
print('Número de outliers por columna:\n')
for col in df_spn_day.loc[:,df_spn_day.columns.str.startswith('generation')]:
    print(col,':',outlier(df_spn_day[col]))
# Out:
# Filas totales: 1461
#
# Número de outliers por columna:
#
# generation biomass : 0
# generation nuclear : 2
# generation other : 55
# generation other renewable : 0
# generation solar : 0
# generation waste : 27
# generation wind onshore : 19
# generation fossil : 2
# generation hydro : 90

# %%
grafica_tendencia(df_spn_day[nrnw].join(df_spn_day[rnw]),columns);

# %%
grafica_pie(df_spn_day[nrnw].join(df_spn_day[rnw]),df_spn_day_.columns[df_spn_day_.columns.str.startswith('generation')],color=colors,title='Generación de energía España 2015-2019');
grafica_pie(df_spn_day[rnw],rnw,color=colorsrwn,title='Generación de energía renovable España 2015-2019');
grafica_pie(df_spn_day[nrnw],rnw,color=colorsnrwn,title='Generación de energía no renovable España 2015-2019');

# %%
sns.lineplot(data=df_spn_year[columns])
# Out:
# <AxesSubplot:xlabel='day_dt'>

# %%
sns.lineplot(data=df_spn_month_2015[columns])
# Out:
# <AxesSubplot:xlabel='month_dt'>

# %%
sns.lineplot(data=df_spn_month_2016[columns])
# Out:
# <AxesSubplot:xlabel='month_dt'>

# %%
sns.lineplot(data=df_spn_month_2017[columns])
# Out:
# <AxesSubplot:xlabel='month_dt'>

# %%
sns.lineplot(data=df_spn_month_2018[columns])
# Out:
# <AxesSubplot:xlabel='month_dt'>

# %%
grafica_estacionalidad(df_spn_day_,columns=columns);

# %%
grafica_acumulada(df_spn_day_,columns=columns);

# %% [markdown]
# ***OBSERVACIONES:***
#
# ---
# ~~~
# Mayor fuente generadora de energía entre el 2015 al 2019:
#
#     - La mayor generadora: energías fósiles.
#
#     * Renovables: la de mayor generación en España es la eólica, seguida de la hidroeléctrica y posteriormente la solar.
#     * No renovables: la mayor generación viene del conjunto de las energías fósiles, que si bien en su conjunto es la mayor generadora en España,
#     si la dividimos en sus grupos encontramos algunas variaciones. La nuclear estaría en una posición cercana a la fósil mayor generada,
#     siendo esta de las energías más constantes.
#
# Estacionalidad:
#
#     * Se destaca, como era previsible, que en la solar y la eólica es más marcada la estacionalidad.
#     Sin embargo, en las fósiles también se pueden ver variaciones en función del mes del año.
#
# Tendencia:
#
#     * Se ha examinado la tendencia. Observando, tanto en el intervalo como en cada periodo anual, se encuentran despuntes puntuales,
#     sin embargo no hay una clara tendencia creciente o decreciente. Para hacer una afirmación de esta índole, visualmente,
#     es necesario ampliar el intervalo temporal y/o añadir algunas variables.
# ~~~
# ---

# %% [markdown]
# ### *1.3.2. Energía generada vs energía demandada:* <a id='132'></a>

# %% [markdown]
# Se pretende comprobar si se satisface la demanda de energía, en el periodo de tiempo evaluado, con la energía que se genera en dicho periodo.
#
# Para ello, se extraen datos de la evolución de demanda de la API del **ree** (https://www.ree.es/es/apidatos).

# %%
ruta_dir='/Users/mcgg/Documents/TheBridge_DataScience_py_local/02_DATA_ANALISIS/EDA_MC/EDA-energia/energy-data/src/data'
file='demand.txt'
ruta_file=os.path.join(ruta_dir,f'{file}')
if os.path.exists(ruta_file):
    print('Archivo ya creado')
else: 
    api_EDA_ev_demand(anios=[2015,2016,2017,2018],trunc='day',file='demand.txt')
# Out:
# Archivo ya creado

# %%
# Se lee el csv de la demanda creado
demand_spn=pd.read_csv('data/demand.txt',sep=';')
# Se reemplaza 'time' quitándole el intervalo
demand_spn['time']=demand_spn['time'].replace({'\+01:00|\+02:00|\+03:00':''},regex=True)

# Se transforma en formato datetime la columna 'time' 
demand_spn['time']=pd.to_datetime(demand_spn['time'], infer_datetime_format=True)
demand_spn.head()
# Out:
#         time  total_demand
# 0 2015-01-02    715038.679
# 1 2015-01-03    698648.512
# 2 2015-01-04    663533.254
# 3 2015-01-05    714784.323
# 4 2015-01-06    640502.590

# %%
demand_spn.groupby('time').mean().plot() #MW
# Out:
# <AxesSubplot:xlabel='time'>

# %%
# Se crea un df para comparar generación y demanda
df_spn_comp_=pd.DataFrame()
df_spn_comp_['total_generation']=df_spn_day_[df_spn_day_.columns[df_spn_day_.columns.str.startswith('generation')]].sum(axis=1)
demand_spn=demand_spn.groupby('time').mean()
demand_spn['total_demand']=demand_spn['total_demand']/24 #MWh
df_spn_comp_=df_spn_comp_.join(demand_spn['total_demand'])
df_spn_comp_['total_demand'][0]=df_spn_comp_['total_demand'].mean()

# %%
# GRAFICA GENERACION vs DEMANDA:
df=df_spn_comp_.copy()
df.index=pd.to_datetime(df.index)
df_spn_month_ = df[df.columns].resample('M').sum(min_count=28)
df_spn_month_['generacion total']=df_spn_month_['total_generation']
fig,eje = plt.subplots()
eje.plot(df_spn_month_['total_demand'],color='black',label='demanda')
df_spn_month_['generacion total'].plot.area(ax=eje,linewidth=0)

eje.legend()
eje.set_ylabel('Total Mensual (MWh)') 
eje.set_xlabel('fecha')
# Out:
# Text(0.5, 0, 'fecha')

# %% [markdown]
# ***OBSERVACIONES:***
#
# ---
# ~~~
# Según los datos proporcionados, la demanda en este periodo de tiempo tiene un balance positivo con respecto a la generación. Esto podría ser uno de los motivos o consecuencias de que España, justo en este periódo, fuera más importadora que exportadora de energía.
#
# El autoabastecimiento, entendido como indicador de equilibrio entre generación y demanda, no se encuentra lejos de darse.
# ~~~
# ---

# %% [markdown]
# ### *1.3.3. Balance eficiencia energética-efectos adversos:* <a id='133'></a>

# %% [markdown]
# Se pretende realizar un primer estudio sobre generación vs efector adversos de la fuentes de energía. Un problema ya conocido por todos es el efecto negativo sobre el planeta que ocasiona la emisión de gases tóxicos a la atmósfera (gases como CO2, etc...). Por lo tanto, a la hora de recomendar una inversión en fuentes de energía es un factor a tener en cuenta.
#
# Es por ello, que para este estudio se prescinde de evaluar aquellas energías que producen esos gases tóxicos como son las energías fósiles. Tampoco se evalúa la hidráulica, porque según varias fuentes, está muy limitada por factores geográficos.

# %%
energies=['generation solar','generation wind onshore', 'generation nuclear']
df_spn_day_=df_spn_day_[['month','year']+energies]

ruta_dir='/Users/mcgg/Documents/TheBridge_DataScience_py_local/02_DATA_ANALISIS/EDA_MC/EDA-energia/energy-data/src/data'
file='p_installed.txt'
ruta_file=os.path.join(ruta_dir,f'{file}')

if os.path.exists(ruta_file):
    print('Archivo ya creado')
else: 
    api_EDA_ev_demand(anios=[2015,2016,2017,2018],trunc='day',file='p_installed.txt')
# Out:
# Archivo ya creado

# %%
# Se lee el csv de la demanda creado
pinstalled_spn=pd.read_csv('data/p_installed.txt',sep=';')
# Se reemplaza 'time' quitándole el intervalo
pinstalled_spn['time']=pinstalled_spn['time'].replace({'\+01:00|\+02:00|\+03:00':''},regex=True)

# Se transforma en formato datetime la columna 'time' 
pinstalled_spn['time']=pd.to_datetime(pinstalled_spn['time'], infer_datetime_format=True)

pinstalled_spn.index=df_spn_month_.index
pinstalled_spn.drop(columns='time',inplace=True)

# %%
pinstalled_spn.index.rename('date',inplace=True)
pinstalled_spn.sample(10)
# Out:
#             nuclear       wind     solar
# date
# 2018-12-31  7117.29  23428.654  4767.386
# 2017-06-30  7572.58  23001.135  4686.752
# 2015-06-30  7572.58  22919.030  4679.518
# 2017-08-31  7572.58  23024.624  4686.522
# 2018-02-28  7117.29  23078.419  4702.022
# 2016-06-30  7572.58  22923.730  4683.473
# 2016-01-31  7572.58  22919.230  4680.972
# 2018-07-31  7117.29  23123.739  4708.076
# 2018-06-30  7117.29  23123.739  4707.761
# 2015-08-31  7572.58  22919.030  4680.004

# %%
# GRAFICA ratio MWh/MW instalado
df=df_spn_day_
columns=energies
df.index=pd.to_datetime(df.index)
df_spn_month_ = df[df.columns].resample('M').sum(min_count=28)

df_ratio=df_spn_month_.copy()
df_ratio.drop(columns=['month','year'],inplace=True)
df_ratio['generation solar']=df_ratio['generation solar']/pinstalled_spn['solar']
df_ratio['generation nuclear']=df_ratio['generation nuclear']/pinstalled_spn['nuclear']
df_ratio['generation wind onshore']=df_ratio['generation wind onshore']/pinstalled_spn['wind']
fig,eje = plt.subplots()

eje.plot(df_ratio)

eje.legend(energies)
eje.set_ylabel('Ratio MWh/MW instalado')
# Out:
# Text(0, 0.5, 'Ratio MWh/MW instalado')

# %% [markdown]
# ***OBSERVACIONES:***
#
# ---
# ~~~
# Se pretende conocer la eficiencia de las fuentes de energía comparando la energía generada en función de la potencia instalada:
#
#     * La que mayor ratio tiene, como era de esperar, es la nuclear. Además, se sabe que desde 1983 hasta la actualidad se han instalado 7 centrales nucleares,
#     aunque algunas han cesado su producción.
#     * Entre la solar y la eólica, también se confirma que la mayor parte del tiempo es más eficiente es la solar.
#
# Teniendo en cuenta solo la eficiencia este estudio la nuclear sería la elegida. Pero habría que evaluar, en cuanto efectos adversos, las consecuencias negativas de esta:
#
#     * Generación de residuos
#     * Impacto social
#     * Seguridad
#
# Las renovables, por su lado, también tienen efectos adversos:
#
#     * Cambios en ecosistemas donde se instalen, esto también ocurre con las no renovables, pero hasta ahora la eólica y solar
#     requieren mayor superficie para llegar a la misma producción que la nuclear.
#     * Dependencia del clima. -> Observación a contrastar en el siguiente apartado.
#     * Se comenta también el impacto social, o impacto visual, sobretodo en la eólica.
# ~~~
# ---

# %% [markdown]
# ### *1.3.4. Influencia del clima en la generación de energía:* <a id='134'></a>

# %% [markdown]
# En este apartado se pretende comprobar si es cierto y hasta que punto que la generación de energía depende de las condiciones climáticas.

# %%
df_weather_city = df_weather_city.drop(['snow_3h_Barcelona', 'snow_3h_Seville'], axis=1)

# %%
correlations = df_weather_city.corr(method='pearson')
fig = plt.figure(figsize=(24, 24))
sns.heatmap(correlations, annot=True, fmt='.2f')
plt.title('Matriz de correlacion')
plt.show()

# %% [markdown]
# ***OBSERVACIONES:***
#
# ---
# ~~~
# El mapa de calor nos indica aquellas variables que tengan mayor correlación ya sea proporcional o inversa. En este caso, se comparan la generación de las distintas fuentes con las condiciones climáticas en el periodo estudiado (en cinco de las ciudades con mayor PIB de España: Sevilla, Barcelona, Madrid, Bilbao y Valencia).
#
# Se confirma que aquellas que tienen mayor afección a los efectos climáticos son las renovables, encabezadas por la solar y seguida de la eólica. Aún así no es una correlación excesiva, los valores son bajos para
# ~~~
# ---

# %% [markdown]
# ##  **1.4. Análisis estadístico**<a id='14'></a>

# %% [markdown]
# ### *1.4.1. Balance eficiencia energética-efectos adversos:* <a id='141'></a>

# %% [markdown]
# ### *1.4.2. Balance eficiencia energética-efectos adversos:* <a id='142'></a>

# %% [markdown]
# ### *1.4.3. Balance eficiencia energética-efectos adversos:* <a id='143'></a>

# %% [markdown]
# ### *1.4.4. Balance eficiencia energética-efectos adversos:* <a id='144'></a>

# %% [markdown]
# #  **2. Conclusiones**<a id='2'></a>
